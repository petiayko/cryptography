go visit the Prairies in June, when for scores on scores of miles you wade knee-deep among Tiger-lilies—what is the one charm wanting?—Water—there is not a drop of water there! Were Niagara but a cataract of sand, would you travel your thousand miles to see it? Why did the poor poet of Tennessee, upon suddenly receiving two handfuls of silver, deliberate whether to buy him a coat, which he sadly needed, or invest his money in a pedestrian trip to Rockaway Beach? Why is almost every robust healthy boy with a robust healthy soul in him, at some time or other crazy to go to sea? Why upon your first voyage as a passenger, did you yourself feel such a mystical vibration, when first told that you and your ship were now out of sight of land? Why did the old Persians hold the sea holy? Why did the Greeks give it a separate deity, and own brother of Jove? Surely all this is not without meaning. And still deeper the meaning of that story of Narcissus, who because he could not grasp the tormenting, mild image he saw in the fountain, plunged into it and was drowned. But that same image, we ourselves see in all rivers and oceans. It is the image of the ungraspable phantom of life; and this is the key to it all.'
KEY_LENGTH = 3

# %%
PLAIN_TEXT = ''
for ch in PLAIN_TEXT_RAW:
    if ch.isalpha():
        PLAIN_TEXT += ch.upper()
PLAIN_TEXT
# Out:
# '...'

# %%
plain_text_statistic = dict()
for i in range(len(PLAIN_TEXT) - 3):
    cut = PLAIN_TEXT[i:i + KEY_LENGTH]
    if cut not in plain_text_statistic:
        plain_text_statistic[cut] = 1
        continue
    plain_text_statistic[cut] += 1
plain_text_statistic = dict(sorted(plain_text_statistic.items(), key=lambda item: item[1], reverse=True))

# %%
cipher_text_statistic = dict()
for i in range(len(CIPHER_TEXT) - 3):
    cut = CIPHER_TEXT[i:i + KEY_LENGTH]
    if cut not in cipher_text_statistic:
        cipher_text_statistic[cut] = 1
        continue
    cipher_text_statistic[cut] += 1
cipher_text_statistic = dict(sorted(cipher_text_statistic.items(), key=lambda item: item[1], reverse=True))

# %%
plain_text_statistic
# Out:
# {'THE': 92,
#  'AND': 50,
#  'ING': 31,
#  'HER': 29,
#  'ERE': 25,
#  'ALL': 20,
#  'EST': 19,
#  'YOU': 19,
#  'VER': 17,
#  'THI': 17,
#  'TER': 17,
#  'STH': 17,
#  'HIS': 16,
#  'ATE': 15,
#  'HES': 15,
#  'THA': 14,
#  'NTH': 14,
#  'EVE': 13,
#  'INT': 13,
#  'HAT': 13,
#  'STR': 13,
#  'EAN': 12,
#  'ITH': 12,
#  'HOU': 12,
#  'OUT': 12,
#  'ETH': 12,
#  'FTH': 12,
#  'ERI': 12,
#  'TTH': 12,
#  'ESA': 12,
#  'TRE': 12,
#  'ENT': 12,
#  'DTH': 12,
#  'OTH': 11,
#  'OFT': 11,
#  'TAN': 11,
#  'STA': 11,
#  'OME': 10,
#  'THO': 10,
#  'LEA': 10,
#  'NDS': 10,
#  'WAT': 10,
#  'HEN': 10,
#  'SAN': 10,
#  'REE': 10,
#  'SOF': 10,
#  'IST': 10,
#  'LAN': 10,
#  'WIT': 10,
#  'RTH': 10,
#  'SEA': 9,
#  'RES': 9,
#  'GHT': 9,
#  'TOF': 9,
#  'HEM': 9,
#  'OUN': 9,
#  'IGH': 9,
#  'OUR': 9,
#  'IES': 9,
#  'EEP': 9,
#  'ERT': 9,
#  'SOM': 8,
#  'NOT': 8,
#  'ORE': 8,
#  'WHE': 8,
#  'REA': 8,
#  'LES': 8,
#  'NTI': 8,
#  'BUT': 8,
#  'VES': 8,
#  'ESS': 8,
#  'NDT': 8,
#  'INA': 8,
# ...

# %%
cipher_text_statistic
# Out:
# {'JKN': 8,
#  'YDF': 7,
#  'MAF': 4,
#  'SRA': 3,
#  'QXP': 3,
#  'YOZ': 3,
#  'FMN': 3,
#  'UVR': 3,
#  'MUB': 3,
#  'MNF': 3,
#  'RAM': 2,
#  'QWL': 2,
#  'OJG': 2,
#  'JZG': 2,
#  'GMB': 2,
#  'NFT': 2,
#  'EPR': 2,
#  'IYI': 2,
#  'KIK': 2,
#  'BIY': 2,
#  'AYH': 2,
#  'IYQ': 2,
#  'OOP': 2,
#  'OPP': 2,
#  'PPR': 2,
#  'PRA': 2,
#  'HRO': 2,
#  'GZL': 2,
#  'EMJ': 2,
#  'NPH': 2,
#  'OQL': 2,
#  'KUV': 2,
#  'ADQ': 2,
#  'DQX': 2,
#  'XRE': 2,
#  'YML': 2,
#  'AFM': 2,
#  'RAH': 2,
#  'AHU': 2,
#  'HUW': 2,
#  'WLU': 2,
#  'POL': 2,
#  'MZZ': 2,
#  'OQO': 2,
#  'ODQ': 2,
#  'VOW': 2,
#  'DDI': 2,
#  'FNS': 2,
#  'IGW': 2,
#  'UJK': 2,
#  'XOI': 2,
#  'AVU': 2,
#  'QOQ': 2,
#  'EJZ': 2,
#  'UBM': 2,
#  'DFR': 1,
#  'FRB': 1,
#  'RBC': 1,
#  'BCN': 1,
#  'CNX': 1,
#  'NXI': 1,
#  'XIC': 1,
#  'ICS': 1,
#  'CSD': 1,
#  'SDD': 1,
#  'DDO': 1,
#  'DOR': 1,
#  'ORS': 1,
#  'RSH': 1,
#  'SHM': 1,
#  'HMC': 1,
#  'MCZ': 1,
#  'CZR': 1,
#  'ZRO': 1,
#  'ROV': 1,
#  'OVC': 1,
# ...

# %%
l = 10
most_freq_gram_plain_text = list(plain_text_statistic.keys())[:l]
most_freq_gram_cipher_text = list(cipher_text_statistic.keys())[:l]

# %%
most_freq_gram_plain_text_pos = dict()
for gram in most_freq_gram_plain_text:
    most_freq_gram_plain_text_pos[gram] = []
    index = -1
    while True:
        index = PLAIN_TEXT.find(gram, index + 1)
        if index == -1:
            break
        most_freq_gram_plain_text_pos[gram].append(index)

# %%
most_freq_gram_cipher_text_pos = dict()
for gram in most_freq_gram_cipher_text:
    most_freq_gram_cipher_text_pos[gram] = []
    index = -1
    while True:
        index = CIPHER_TEXT.find(gram, index + 1)
        if index == -1:
            break
        most_freq_gram_cipher_text_pos[gram].append(index)

# %%
most_freq_gram_plain_text_pos
# Out:
# {'THE': [155,
#   170,
#   203,
#   225,
#   274,
#   396,
#   546,
#   592,
#   739,
#   746,
#   778,
#   805,
#   827,
#   848,
#   870,
#   884,
#   911,
#   1011,
#   1057,
#   1166,
#   1188,
#   1207,
#   1278,
#   1350,
#   1433,
#   1456,
#   1483,
#   1525,
#   1578,
#   1676,
#   1689,
#   1713,
#   1763,
#   1821,
#   1828,
#   1847,
#   1868,
#   1913,
#   1934,
#   1944,
#   1978,
#   1983,
#   1999,
#   2022,
#   2068,
#   2088,
#   2093,
#   2115,
#   2134,
#   2146,
#   2180,
#   2187,
#   2210,
#   2313,
#   2327,
#   2336,
#   2355,
#   2485,
#   2531,
#   2681,
#   2695,
#   2715,
#   2784,
#   2795,
#   2808,
#   2822,
#   2832,
#   2928,
#   3061,
#   3067,
#   3093,
#   3208,
#   3236,
#   3266,
#   3348,
#   3371,
#   3393,
#   3471,
#   3546,
#   3650,
#   3671,
#   3701,
#   3853,
#   3871,
#   3887,
#   3925,
#   3981,
#   4038,
#   4067,
#   4158,
#   4168,
#   4204],
#  'AND': [80,
#   149,
#   212,
#   383,
#   422,
#   465,
#   555,
#   663,
#   1004,
# ...

# %%
most_freq_gram_cipher_text_pos
# Out:
# {'JKN': [75, 90, 123, 666, 747, 768, 804, 831],
#  'YDF': [0, 69, 132, 160, 303, 342, 924],
#  'MAF': [117, 459, 495, 687],
#  'SRA': [27, 468, 933],
#  'QXP': [39, 591, 909],
#  'YOZ': [81, 327, 759],
#  'FMN': [344, 461, 689],
#  'UVR': [351, 486, 717],
#  'MUB': [426, 896, 914],
#  'MNF': [462, 690, 723]}

# %% [markdown]
# ### На этом этапе при ручном анализе структур most_freq_gram_plain_text_pos  и most_freq_gram_cipher_text_pos видно соответствие 3-грамм YDF и AND, также определяется, с какой позиции ОТ началось шифрование - с первого AND

# %%
PLAIN_TEXT[80:92]
# Out:
# 'ANDNOTHINGPA'

# %%
CIPHER_TEXT[:12]
# Out:
# 'YDFRBCNXICSD'

# %%
cipher_grams = []
for gram in ['YDF', 'CSD', 'NXI']:
    cipher_grams.append([ALPHABET.index(ch) for ch in gram])
plain_grams = []
for gram in ['AND', 'GPA', 'HIN']:
    plain_grams.append([ALPHABET.index(ch) for ch in gram])

# %%
cipher_grams
# Out:
# [[24, 3, 5], [2, 18, 3], [13, 23, 8]]

# %%
plain_grams
# Out:
# [[0, 13, 3], [6, 15, 0], [7, 8, 13]]

# %%
plain_grams_opposite = [[13, 1, 3], [0, 17, 4], [9, 13, 0]]  # посчитано на калькуляторе

# %%
key = [[15, 22, 14], [8, 8, 5], [8, 1, 6]]  # посчитано на калькуляторе
